# %%
import GEOparse
import pandas as pd
import numpy as np

# %%
hypo = GEOparse.get_GEO("GSE36674")
# Out:
# 17-Aug-2023 14:56:53 DEBUG utils - Directory ./ already exists. Skipping.
# 17-Aug-2023 14:56:53 INFO GEOparse - File already exist: using local version.
# 17-Aug-2023 14:56:53 INFO GEOparse - Parsing ./GSE36674_family.soft.gz:
# 17-Aug-2023 14:56:53 DEBUG GEOparse - DATABASE: GeoMiame
# 17-Aug-2023 14:56:53 DEBUG GEOparse - SERIES: GSE36674
# 17-Aug-2023 14:56:53 DEBUG GEOparse - PLATFORM: GPL6246
# 17-Aug-2023 14:56:55 DEBUG GEOparse - SAMPLE: GSM898375
# 17-Aug-2023 14:56:55 DEBUG GEOparse - SAMPLE: GSM898376
# 17-Aug-2023 14:56:55 DEBUG GEOparse - SAMPLE: GSM898377
# 17-Aug-2023 14:56:55 DEBUG GEOparse - SAMPLE: GSM898378
# 17-Aug-2023 14:56:55 DEBUG GEOparse - SAMPLE: GSM898379
# 17-Aug-2023 14:56:55 DEBUG GEOparse - SAMPLE: GSM898380
# 17-Aug-2023 14:56:55 DEBUG GEOparse - SAMPLE: GSM898381
# 17-Aug-2023 14:56:55 DEBUG GEOparse - SAMPLE: GSM898382
# 17-Aug-2023 14:56:55 DEBUG GEOparse - SAMPLE: GSM898383
# 17-Aug-2023 14:56:56 DEBUG GEOparse - SAMPLE: GSM898384
# ...

# %%
hypo.gsms
# Out:
# {'GSM898375': <SAMPLE: GSM898375>,
#  'GSM898376': <SAMPLE: GSM898376>,
#  'GSM898377': <SAMPLE: GSM898377>,
#  'GSM898378': <SAMPLE: GSM898378>,
#  'GSM898379': <SAMPLE: GSM898379>,
#  'GSM898380': <SAMPLE: GSM898380>,
#  'GSM898381': <SAMPLE: GSM898381>,
#  'GSM898382': <SAMPLE: GSM898382>,
#  'GSM898383': <SAMPLE: GSM898383>,
#  'GSM898384': <SAMPLE: GSM898384>,
#  'GSM898385': <SAMPLE: GSM898385>,
#  'GSM898386': <SAMPLE: GSM898386>,
#  'GSM898387': <SAMPLE: GSM898387>,
#  'GSM898388': <SAMPLE: GSM898388>,
#  'GSM898389': <SAMPLE: GSM898389>,
#  'GSM898390': <SAMPLE: GSM898390>,
#  'GSM898391': <SAMPLE: GSM898391>,
#  'GSM898392': <SAMPLE: GSM898392>,
#  'GSM898393': <SAMPLE: GSM898393>,
#  'GSM898394': <SAMPLE: GSM898394>,
#  'GSM898395': <SAMPLE: GSM898395>,
#  'GSM898396': <SAMPLE: GSM898396>,
#  'GSM898397': <SAMPLE: GSM898397>,
#  'GSM898398': <SAMPLE: GSM898398>,
#  'GSM898399': <SAMPLE: GSM898399>,
#  'GSM898400': <SAMPLE: GSM898400>,
#  'GSM898401': <SAMPLE: GSM898401>,
# ...

# %%
def get_GEO(accession, gene_ID, tissue):
    GEOparse.get_GEO(accession)
    pass
